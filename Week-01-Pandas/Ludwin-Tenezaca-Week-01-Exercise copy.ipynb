# %% [markdown]
# # First print your name in the cell below then save this file. (or something nice about your instructor)

# %%
# In this cell print your name 

# Ludwin

# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
from pathlib import Path
file_location = Path('/workspaces/ds-fall-2026/Week-01-Pandas/data/listings.csv')

mydata = pd.read_csv(file_location)
print(mydata)
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 
less_than_100 = mydata[mydata["price"] < 100]
print(less_than_100)
# Out:
#              id                                               name    host_id  \
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 4          5178                   Large Furnished Room Near B'way　       8967
# 5          5203                 Cozy Clean Guest Room - Family Apt       7490
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# ...         ...                                                ...        ...
# 46520  44804690    Cozy place, peaceful,  friendly and affordable.  362419479
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.
df_bk = mydata[mydata["neighbourhood_group"] == "Brooklyn"]
print(df_bk)
# Out:
#              id                                               name    host_id  \
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 11         6848                   Only 2 stops to Manhattan studio      15991
# ...         ...                                                ...        ...
# 46517  44802032                  A very large room in Williamsburg  213793805
# 46518  44802224  Unique & beautiful design! Skylights-Washer/dryer  143513836
# 46519  44803201  1200 SF Duplex apt in an old shoe factory/ mon...     921746
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.
bk_less_100 = df_bk[df_bk["price"] < 100]
print(bk_less_100)
print(len(bk_less_100))
# Out:
#              id                                               name    host_id  \
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 21        10452                              Large B&B Style rooms      35935
# 22        10962            Lovely Room 2; Garden; Best area, Legal       9744
# ...         ...                                                ...        ...
# 46510  44798876  Unique & beautiful design! Skylights-Washer/dryer  143513836
# 46517  44802032                  A very large room in Williamsburg  213793805
# 46518  44802224  Unique & beautiful design! Skylights-Washer/dryer  143513836
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
# How many total are there that have those names

host_names = mydata[mydata["host_name"].isin(["Michael", "David", "John", "Daniel"])]
print(len(host_names))
# Out:
# 1258

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same

mydata["adjusted_price"] = [mydata["price"] + 100 if group == 'Williamsburg' else mydata["price"] for group in mydata["neighbourhood"]]
print(mydata["neighbourhood"])
print(mydata["price"])
print(mydata["adjusted_price"])

# Example code from GeeksForGeeks below, which I used as inspiration for my code:
# site link: https://www.geeksforgeeks.org/pandas/python-creating-a-pandas-dataframe-column-based-on-a-given-condition/
# df['Price'] = [1500 if x == 'Music' else 800 for x in df['Event']]
# print(df)
# Out:
# 0                   Midtown
# 1              Clinton Hill
# 2        Bedford-Stuyvesant
# 3               Sunset Park
# 4            Hell's Kitchen
#                 ...
# 46522              Gramercy
# 46523    Washington Heights
# 46524         East Flatbush
# 46525       Upper West Side
# 46526             Gravesend
# Name: neighbourhood, Length: 46527, dtype: str
# 0        175
# 1         75
# 2         60
# 3        175
# 4         65
#         ...
# 46522    145
# 46523     87
# 46524     59
# 46525     80
# 46526     66
# Name: price, Length: 46527, dtype: int64
# 0        0        175
# 1         75
# 2         60
# 3      ...
# 1        0        175
# 1         75
# 2         60
# 3      ...
# 2        0        175
# 1         75
# 2         60
# 3      ...
# 3        0        175
# 1         75
# 2         60
# 3      ...
# 4        0        175
# 1         75
# 2         60
# 3      ...
#                                ...
# 46522    0        175
# 1         75
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared. 
print("Percent of private rooms: " + str((len(mydata["room_type"].isin(["Private"])) / len(mydata)) * 100) + "%")
print("Percent of shared rooms: " + str((1-(len(mydata["room_type"].isin(["Private"])) / len(mydata))) * 100) + "%")
# Out:
# Percent of private rooms: 100.0%
# Percent of shared rooms: 0.0%

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
print(mydata.groupby(mydata["neighbourhood_group"]).count())
# Out:
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Bronx                 1183   1181     1183       1183           1183
# Brooklyn             18632  18626    18632      18624          18632
# Manhattan            20580  20570    20580      20555          20580
# Queens                5791   5791     5791       5789           5791
# Staten Island          341    341      341        341            341
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                    1183       1183       1183   1183            1183
# Brooklyn                18632      18632      18632  18632           18632
# Manhattan               20580      20580      20580  20580           20580
# Queens                   5791       5791       5791   5791            5791
# Staten Island             341        341        341    341             341
#
# ...

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 
print(mydata.groupby(mydata["price"]).mean(numeric_only=True))
# Out:
#                  id       host_id   latitude  longitude  minimum_nights  \
# price
# 0      4.142158e+07  2.724993e+08  40.740877 -73.983768        1.363636
# 9      2.660242e+07  2.000073e+08  40.752740 -73.996470       60.000000
# 10     2.317747e+07  1.207173e+08  40.748870 -73.925103        3.000000
# 11     9.026479e+06  2.266437e+06  40.723140 -73.979290        5.000000
# 14     3.936561e+07  1.560763e+08  40.728685 -73.876260       25.500000
# ...             ...           ...        ...        ...             ...
# 9000   2.046450e+07  4.951907e+07  40.710500 -73.815890        5.000000
# 9990   4.308991e+06  6.195809e+06  40.726070 -73.988670        4.000000
# 9992   3.301431e+07  2.484719e+08  40.762060 -73.960420        1.000000
# 9999   2.640540e+07  1.710957e+08  40.734281 -73.984472        2.941176
# 10000  2.817308e+07  1.534213e+08  40.750860 -73.973571       11.571429
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# price
# ...

# %%
# 2.5. Using `groupby`, find the mean price for each room_type. 
print(mydata[["room_type", "price"]].groupby(mydata["room_type"]).mean(numeric_only=True))
# Out:
#                       price
# room_type
# Entire home/apt  199.395950
# Hotel room       275.015075
# Private room      91.453084
# Shared room       87.063830

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 
print(mydata[["neighbourhood_group", "price"]].groupby("neighbourhood_group").agg(["min"]))
print(mydata[["neighbourhood_group", "price"]].groupby("neighbourhood_group").agg(["max"]))
# Out:
#                     price
#                       min
# neighbourhood_group
# Bronx                  16
# Brooklyn                0
# Manhattan               0
# Queens                  0
# Staten Island          19
#                      price
#                        max
# neighbourhood_group
# Bronx                 1404
# Brooklyn             10000
# Manhattan            10000
# Queens               10000
# Staten Island         1200

# %%
# 4. Using `groupby`, find the mean price for each room_type in each neighbourhood_group.
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["mean"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # 4. Using `groupby`, find the mean price for each room_type in each neighbourhood_group.
# ----> 2 print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("price").agg(["mean"]))
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/apply.py:297, in Apply.agg(self)
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["count"]))
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["min"]))
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["max"]))
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["mean"]))
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["medie "]))
print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["std"]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 4
#       1 # 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices
#       2 # for each room type in each neighbourhood_group.
#       3
# ----> 4 print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["count"]))
#       5 print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["min"]))
#       6 print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["max"]))
#       7 print(mydata[["neighbourhood_group", "room_type", "price"]].groupby("").agg(["mean"]))
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
# ...

# %% [markdown]
# # Load, Merge, and Export files.
# 1. Load the `prices.csv` and the `n_listings.csv`
#     * Having an error..? Inspect the actual csv file if you're having trouble
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv` into the data folder.
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
second_file_location = Path('/workspaces/ds-fall-2026/Week-01-Pandas/data/prices.csv')
third_file_location = Path('/workspaces/ds-fall-2026/Week-01-Pandas/data/n_listings.csv')

prices = pd.read_csv(second_file_location)
number_listings = pd.read_csv(third_file_location)

# %%
# 2. Do join that keeps all the records for each table.
joined_table = prices+number_listings
print(joined_table)
# Out:
#     mean_price neighbourhood_group neighbourhood_group;n_listings
# 0          NaN                 NaN                            NaN
# 1          NaN                 NaN                            NaN
# 2          NaN                 NaN                            NaN
# 3          NaN                 NaN                            NaN
# 4          NaN                 NaN                            NaN

# %%
# 3. Save your joined csv as `joined.csv` into the data folder. 
myPath = Path('/workspaces/ds-fall-2026/Week-01-Pandas/data/joined_table.csv')
joined_table.to_csv(myPath)

# %%
# 4. Load your newly saved file, see if it looks the same.  If not, try saving with argument `index=False`
myFile = pd.read_csv(myPath)
print(myFile)
# Out:
#    Unnamed: 0   mean_price  neighbourhood_group  \
# 0           0          NaN                  NaN
# 1           1          NaN                  NaN
# 2           2          NaN                  NaN
# 3           3          NaN                  NaN
# 4           4          NaN                  NaN
#
#    neighbourhood_group;n_listings
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# # Extra Credit
# Every question below this cell is extra credit and optional.

# %% [markdown]
# ### 2. (Very Easy) Find other cool Panda packages / add ons and show us what they can do well. And how you installed them.

# %% [markdown]
# ### 3. (Medium) Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %% [markdown]
# ### (Hard) Load the Game Logs for 2022 and add the column names using a dictionary.
# * [Link to the data page](https://www.retrosheet.org/gamelogs/)
# * [Link to the column names](https://procatinator.com/)
# * haha, gotta find them yourself!

# %% [markdown]
# ### (Extra Hard) Download the files for the past 5 years into a new folder and add them all into one data frame using pandas, then save that new file.
# * Try to not hard code in the file names. We want to do this programmatically because what if we want to add new/more file names in the future.
